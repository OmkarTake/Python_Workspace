# %%
name = "Omkar"
print(name)
print(type(name))
print(id(name))
# Out:
# Omkar
# <class 'str'>
# 2813629178256

# %%
print(name[0], name[4])      # indexing
print(name[1], name[3])      # indexing
print(name[2], name[4])      # indexing
print(name[3], name[0])      # indexing
print(name[4], name[1])      # indexing
print(name[0], name[1])      # indexing

print(name[-1], name[-5])    # negative indexing
print(name[-2], name[-4])    # negative indexing
print(name[-3], name[-1])    # negative indexing
print(name[-4], name[-2])    # negative indexing
print(name[-5], name[-3])    # negative indexing
# Out:
# O r
# m a
# k r
# a O
# r m
# O m
# r O
# a m
# k r
# m a
# O k
