# %%
# Slicing problem
n = "Omkar Take"
#    01234 5678

# %%
print(n[0:5])  
print(n[6:10]) 
print(n[:2])  
print(n[2:5]) 
print(n[::-1])  
print(n[:5:2])  
print(n[:])  
print(n[::2]) 
print(n[1::2])  
print(n[-4:])
# Out:
# Omkar
# Take
# Om
# kar
# ekaT rakmO
# Okr
# Omkar Take
# OkrTk
# ma ae
# Take
